# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('./medals.csv')
data.head()
# Out:
#   discipline_title     slug_game    event_title event_gender medal_type  \
# 0          Curling  beijing-2022  Mixed Doubles        Mixed       GOLD
# 1          Curling  beijing-2022  Mixed Doubles        Mixed       GOLD
# 2          Curling  beijing-2022  Mixed Doubles        Mixed     SILVER
# 3          Curling  beijing-2022  Mixed Doubles        Mixed     SILVER
# 4          Curling  beijing-2022  Mixed Doubles        Mixed     BRONZE
#
#   participant_type participant_title  \
# 0         GameTeam             Italy
# 1         GameTeam             Italy
# 2         GameTeam            Norway
# 3         GameTeam            Norway
# 4         GameTeam            Sweden
#
#                                          athlete_url     athlete_full_name  \
# 0  https://olympics.com/en/athletes/stefania-cons...  Stefania CONSTANTINI
# 1      https://olympics.com/en/athletes/amos-mosaner          Amos MOSANER
# 2  https://olympics.com/en/athletes/kristin-skaslien      Kristin SKASLIEN
# 3  https://olympics.com/en/athletes/magnus-nedreg...    Magnus NEDREGOTTEN
# 4     https://olympics.com/en/athletes/almida-de-val         Almida DE VAL
#
#   country_name country_code country_3_letter_code
# 0        Italy           IT                   ITA
# 1        Italy           IT                   ITA
# 2       Norway           NO                   NOR
# 3       Norway           NO                   NOR
# 4       Sweden           SE                   SWE

# %%
data.isna().sum()
# Out:
# discipline_title             0
# slug_game                    0
# event_title                  0
# event_gender                 0
# medal_type                   0
# participant_type             0
# participant_title        15113
# athlete_url               4670
# athlete_full_name         3624
# country_name                 0
# country_code              1502
# country_3_letter_code        0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21697 entries, 0 to 21696
# Data columns (total 12 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   discipline_title       21697 non-null  object
#  1   slug_game              21697 non-null  object
#  2   event_title            21697 non-null  object
#  3   event_gender           21697 non-null  object
#  4   medal_type             21697 non-null  object
#  5   participant_type       21697 non-null  object
#  6   participant_title      6584 non-null   object
#  7   athlete_url            17027 non-null  object
#  8   athlete_full_name      18073 non-null  object
#  9   country_name           21697 non-null  object
#  10  country_code           20195 non-null  object
#  11  country_3_letter_code  21697 non-null  object
# dtypes: object(12)
# memory usage: 2.0+ MB

# %%
data = data.fillna("NA")

# %%
data.isna().sum()
# Out:
# discipline_title         0
# slug_game                0
# event_title              0
# event_gender             0
# medal_type               0
# participant_type         0
# participant_title        0
# athlete_url              0
# athlete_full_name        0
# country_name             0
# country_code             0
# country_3_letter_code    0
# dtype: int64

# %%
data.tail()
# Out:
#       discipline_title    slug_game                      event_title  \
# 21692    Weightlifting  athens-1896  heavyweight - one hand lift men
# 21693    Weightlifting  athens-1896  heavyweight - one hand lift men
# 21694    Weightlifting  athens-1896  heavyweight - two hand lift men
# 21695    Weightlifting  athens-1896  heavyweight - two hand lift men
# 21696    Weightlifting  athens-1896  heavyweight - two hand lift men
#
#       event_gender medal_type participant_type participant_title  \
# 21692          Men     SILVER          Athlete                NA
# 21693          Men     BRONZE          Athlete                NA
# 21694          Men       GOLD          Athlete                NA
# 21695          Men     SILVER          Athlete                NA
# 21696          Men     BRONZE          Athlete                NA
#
#                                              athlete_url  \
# 21692      https://olympics.com/en/athletes/viggo-jensen
# 21693                                                 NA
# 21694      https://olympics.com/en/athletes/viggo-jensen
# 21695  https://olympics.com/en/athletes/launceston-el...
# 21696   https://olympics.com/en/athletes/sotirios-versis
#
#              athlete_full_name   country_name country_code  \
# 21692             Viggo JENSEN        Denmark           DK
# 21693  Alexandros Nikolopoulos         Greece           GR
# 21694             Viggo JENSEN        Denmark           DK
# 21695        Launceston ELLIOT  Great Britain           GB
# 21696          Sotirios VERSIS         Greece           GR
#
#       country_3_letter_code
# 21692                   DEN
# 21693                   GRE
# 21694                   DEN
# 21695                   GBR
# 21696                   GRE

# %%
def extractYear(str):
    return str.split('-')[-1]

# %%
data['year'] = data['slug_game'].apply(lambda x:extractYear(x))

# %%
data.head()
# Out:
#   discipline_title     slug_game    event_title event_gender medal_type  \
# 0          Curling  beijing-2022  Mixed Doubles        Mixed       GOLD
# 1          Curling  beijing-2022  Mixed Doubles        Mixed       GOLD
# 2          Curling  beijing-2022  Mixed Doubles        Mixed     SILVER
# 3          Curling  beijing-2022  Mixed Doubles        Mixed     SILVER
# 4          Curling  beijing-2022  Mixed Doubles        Mixed     BRONZE
#
#   participant_type participant_title  \
# 0         GameTeam             Italy
# 1         GameTeam             Italy
# 2         GameTeam            Norway
# 3         GameTeam            Norway
# 4         GameTeam            Sweden
#
#                                          athlete_url     athlete_full_name  \
# 0  https://olympics.com/en/athletes/stefania-cons...  Stefania CONSTANTINI
# 1      https://olympics.com/en/athletes/amos-mosaner          Amos MOSANER
# 2  https://olympics.com/en/athletes/kristin-skaslien      Kristin SKASLIEN
# 3  https://olympics.com/en/athletes/magnus-nedreg...    Magnus NEDREGOTTEN
# 4     https://olympics.com/en/athletes/almida-de-val         Almida DE VAL
#
#   country_name country_code country_3_letter_code  year
# 0        Italy           IT                   ITA  2022
# 1        Italy           IT                   ITA  2022
# 2       Norway           NO                   NOR  2022
# 3       Norway           NO                   NOR  2022
# 4       Sweden           SE                   SWE  2022

# %%
def extractLoc(str):
    return "-".join(i for i in str.split('-')[0:-1])

# %%
data['olympic_location'] = data['slug_game'].apply(lambda x:extractLoc(x))

# %%
data.head()
# Out:
#   discipline_title     slug_game    event_title event_gender medal_type  \
# 0          Curling  beijing-2022  Mixed Doubles        Mixed       GOLD
# 1          Curling  beijing-2022  Mixed Doubles        Mixed       GOLD
# 2          Curling  beijing-2022  Mixed Doubles        Mixed     SILVER
# 3          Curling  beijing-2022  Mixed Doubles        Mixed     SILVER
# 4          Curling  beijing-2022  Mixed Doubles        Mixed     BRONZE
#
#   participant_type participant_title  \
# 0         GameTeam             Italy
# 1         GameTeam             Italy
# 2         GameTeam            Norway
# 3         GameTeam            Norway
# 4         GameTeam            Sweden
#
#                                          athlete_url     athlete_full_name  \
# 0  https://olympics.com/en/athletes/stefania-cons...  Stefania CONSTANTINI
# 1      https://olympics.com/en/athletes/amos-mosaner          Amos MOSANER
# 2  https://olympics.com/en/athletes/kristin-skaslien      Kristin SKASLIEN
# 3  https://olympics.com/en/athletes/magnus-nedreg...    Magnus NEDREGOTTEN
# 4     https://olympics.com/en/athletes/almida-de-val         Almida DE VAL
#
#   country_name country_code country_3_letter_code  year olympic_location
# 0        Italy           IT                   ITA  2022          beijing
# 1        Italy           IT                   ITA  2022          beijing
# 2       Norway           NO                   NOR  2022          beijing
# 3       Norway           NO                   NOR  2022          beijing
# 4       Sweden           SE                   SWE  2022          beijing

# %%
data.drop(['athlete_url'], inplace=True, axis='columns')

# %%
data.head()
# Out:
#   discipline_title     slug_game    event_title event_gender medal_type  \
# 0          Curling  beijing-2022  Mixed Doubles        Mixed       GOLD
# 1          Curling  beijing-2022  Mixed Doubles        Mixed       GOLD
# 2          Curling  beijing-2022  Mixed Doubles        Mixed     SILVER
# 3          Curling  beijing-2022  Mixed Doubles        Mixed     SILVER
# 4          Curling  beijing-2022  Mixed Doubles        Mixed     BRONZE
#
#   participant_type participant_title     athlete_full_name country_name  \
# 0         GameTeam             Italy  Stefania CONSTANTINI        Italy
# 1         GameTeam             Italy          Amos MOSANER        Italy
# 2         GameTeam            Norway      Kristin SKASLIEN       Norway
# 3         GameTeam            Norway    Magnus NEDREGOTTEN       Norway
# 4         GameTeam            Sweden         Almida DE VAL       Sweden
#
#   country_code country_3_letter_code  year olympic_location
# 0           IT                   ITA  2022          beijing
# 1           IT                   ITA  2022          beijing
# 2           NO                   NOR  2022          beijing
# 3           NO                   NOR  2022          beijing
# 4           SE                   SWE  2022          beijing

# %%
data.shape
# Out:
# (21697, 13)

# %%
import re

def removePunctuationsAndNumbers(text):
    newText = re.sub('[^A-Za-z]+', ' ', text).strip()
    return newText

# %%
data['participant_title_cleaned'] = data['participant_title'].apply(lambda x:removePunctuationsAndNumbers(x))

# %%
data.iloc[np.where((data['country_name'] != data['participant_title']) & (data['participant_title_cleaned'] != 'NA'))[0]]
# Out:
#        discipline_title     slug_game                 event_title  \
# 30     Freestyle Skiing  beijing-2022          Mixed Team Aerials
# 31     Freestyle Skiing  beijing-2022          Mixed Team Aerials
# 81            Snowboard  beijing-2022  Mixed Team Snowboard Cross
# 82            Snowboard  beijing-2022  Mixed Team Snowboard Cross
# 83            Snowboard  beijing-2022  Mixed Team Snowboard Cross
# ...                 ...           ...                         ...
# 21683            Tennis   athens-1896                 doubles men
# 21684            Tennis   athens-1896                 doubles men
# 21685            Tennis   athens-1896                 doubles men
# 21686            Tennis   athens-1896                 doubles men
# 21687            Tennis   athens-1896                 doubles men
#
#       event_gender medal_type participant_type           participant_title  \
# 30           Mixed       GOLD         GameTeam               United States
# 31           Mixed     SILVER         GameTeam                       China
# 81           Mixed       GOLD         GameTeam  United States of America 1
# 82           Mixed       GOLD         GameTeam  United States of America 1
# 83           Mixed     SILVER         GameTeam                     Italy 1
# ...            ...        ...              ...                         ...
# 21683          Men       GOLD         GameTeam               Mixed team #2
# 21684          Men     SILVER         GameTeam              Greece team #1
# 21685          Men     SILVER         GameTeam              Greece team #1
# 21686          Men     BRONZE         GameTeam               Mixed team #1
# 21687          Men     BRONZE         GameTeam               Mixed team #1
#
#              athlete_full_name                country_name country_code  \
# 30                          NA    United States of America           US
# 31                          NA  People's Republic of China           CN
# 81            Nick BAUMGARTNER    United States of America           US
# 82          Lindsey JACOBELLIS    United States of America           US
# 83               Omar VISINTIN                       Italy           IT
# ...                        ...                         ...          ...
# 21683              Fritz Traun                         MIX           NA
# 21684       Demetrius Casdagli                      Greece           GR
# 21685  Dimitrios PETROKOKKINOS                      Greece           GR
# 21686              Edwin FLACK                         MIX           NA
# 21687  George Stuart ROBERTSON                         MIX           NA
#
#       country_3_letter_code  year olympic_location participant_title_cleaned
# 30                      USA  2022          beijing             United States
# 31                      CHN  2022          beijing                     China
# 81                      USA  2022          beijing  United States of America
# 82                      USA  2022          beijing  United States of America
# 83                      ITA  2022          beijing                     Italy
# ...                     ...   ...              ...                       ...
# 21683                   MIX  1896           athens                Mixed team
# 21684                   GRE  1896           athens               Greece team
# 21685                   GRE  1896           athens               Greece team
# 21686                   MIX  1896           athens                Mixed team
# 21687                   MIX  1896           athens                Mixed team
#
# [6200 rows x 14 columns]

# %%
data['medal_type'].value_counts().index
# Out:
# Index(['BRONZE', 'GOLD', 'SILVER'], dtype='object')

# %%
plt.bar(data['medal_type'].value_counts().index, data['medal_type'].value_counts())
# Out:
# <BarContainer object of 3 artists>

# %%
df = data.groupby(['country_name']).count()['medal_type'].sort_values(ascending=False)[0:10].sort_values()
# plt.figure(figsize=(10,30))
df.plot.barh(df.index, df.values)
plt.title("Top 10 countries with maximum medals overall")
plt.show()

# %%
data['year'] = pd.to_numeric(data['year'])

# %%
df = data[(data['year'] <= 2022) & (data['year'] >= 2017)].groupby(['country_name']).count()['medal_type'].sort_values(ascending=False)[0:10].sort_values()
# plt.figure(figsize=(10,30))
df.plot.barh(df.index, df.values)
plt.title("Top 10 countries with maximum medals within the year 2017 and 2022")
plt.show()

# %%
data.head(2)
# Out:
#   discipline_title     slug_game    event_title event_gender medal_type  \
# 0          Curling  beijing-2022  Mixed Doubles        Mixed       GOLD
# 1          Curling  beijing-2022  Mixed Doubles        Mixed       GOLD
#
#   participant_type participant_title     athlete_full_name country_name  \
# 0         GameTeam             Italy  Stefania CONSTANTINI        Italy
# 1         GameTeam             Italy          Amos MOSANER        Italy
#
#   country_code country_3_letter_code  year olympic_location  \
# 0           IT                   ITA  2022          beijing
# 1           IT                   ITA  2022          beijing
#
#   participant_title_cleaned
# 0                     Italy
# 1                     Italy

# %%
df = pd.pivot_table(
    data[(data['year'] <= 2022) & (data['year'] >= 2017)], 
    index=['country_name'], 
    columns=['medal_type'], 
    aggfunc='count'
)['country_3_letter_code'].fillna(0).astype(int)
df['total_medals'] = df.sum(axis=1, numeric_only=True).astype(int)
df = df.sort_values(by=['total_medals'], ascending=False)

# %%
df
# Out:
# medal_type                  BRONZE  GOLD  SILVER  total_medals
# country_name
# United States of America        50    59      63           172
# People's Republic of China      23    57      50           130
# ROC                             44    29      46           119
# Germany                         35    44      38           117
# Japan                           31    35      25            91
# ...                            ...   ...     ...           ...
# Kuwait                           1     0       0             1
# Liechtenstein                    1     0       0             1
# Lithuania                        0     0       1             1
# North Macedonia                  0     0       1             1
# Saudi Arabia                     0     0       1             1
#
# [95 rows x 4 columns]

# %%
data
# Out:
#       discipline_title     slug_game                      event_title  \
# 0              Curling  beijing-2022                    Mixed Doubles
# 1              Curling  beijing-2022                    Mixed Doubles
# 2              Curling  beijing-2022                    Mixed Doubles
# 3              Curling  beijing-2022                    Mixed Doubles
# 4              Curling  beijing-2022                    Mixed Doubles
# ...                ...           ...                              ...
# 21692    Weightlifting   athens-1896  heavyweight - one hand lift men
# 21693    Weightlifting   athens-1896  heavyweight - one hand lift men
# 21694    Weightlifting   athens-1896  heavyweight - two hand lift men
# 21695    Weightlifting   athens-1896  heavyweight - two hand lift men
# 21696    Weightlifting   athens-1896  heavyweight - two hand lift men
#
#       event_gender medal_type participant_type participant_title  \
# 0            Mixed       GOLD         GameTeam             Italy
# 1            Mixed       GOLD         GameTeam             Italy
# 2            Mixed     SILVER         GameTeam            Norway
# 3            Mixed     SILVER         GameTeam            Norway
# 4            Mixed     BRONZE         GameTeam            Sweden
# ...            ...        ...              ...               ...
# 21692          Men     SILVER          Athlete                NA
# 21693          Men     BRONZE          Athlete                NA
# 21694          Men       GOLD          Athlete                NA
# 21695          Men     SILVER          Athlete                NA
# 21696          Men     BRONZE          Athlete                NA
#
#              athlete_full_name   country_name country_code  \
# 0         Stefania CONSTANTINI          Italy           IT
# 1                 Amos MOSANER          Italy           IT
# 2             Kristin SKASLIEN         Norway           NO
# 3           Magnus NEDREGOTTEN         Norway           NO
# 4                Almida DE VAL         Sweden           SE
# ...                        ...            ...          ...
# 21692             Viggo JENSEN        Denmark           DK
# 21693  Alexandros Nikolopoulos         Greece           GR
# 21694             Viggo JENSEN        Denmark           DK
# 21695        Launceston ELLIOT  Great Britain           GB
# 21696          Sotirios VERSIS         Greece           GR
#
#       country_3_letter_code  year olympic_location participant_title_cleaned
# 0                       ITA  2022          beijing                     Italy
# 1                       ITA  2022          beijing                     Italy
# 2                       NOR  2022          beijing                    Norway
# 3                       NOR  2022          beijing                    Norway
# 4                       SWE  2022          beijing                    Sweden
# ...                     ...   ...              ...                       ...
# 21692                   DEN  1896           athens                        NA
# 21693                   GRE  1896           athens                        NA
# 21694                   DEN  1896           athens                        NA
# 21695                   GBR  1896           athens                        NA
# 21696                   GRE  1896           athens                        NA
#
# [21697 rows x 14 columns]

# %%
df = pd.pivot_table(
    data,
    index=['discipline_title'],
    columns=['medal_type'],
    aggfunc='count'
)['country_3_letter_code'].fillna(0).astype(int)
df['total_medals'] = df.sum(axis=1, numeric_only=True).astype(int)
# df = df.sort_values(by=['total_medals'], ascending=False)

# %%
df = df.sort_values(by=['total_medals'])
plt.figure(figsize=(10,30))
df['total_medals'].plot.barh(df['total_medals'].index, df['total_medals'].values)
# Out:
# <Axes: ylabel='discipline_title'>

# %%
data.head()
# Out:
#   discipline_title     slug_game    event_title event_gender medal_type  \
# 0          Curling  beijing-2022  Mixed Doubles        Mixed       GOLD
# 1          Curling  beijing-2022  Mixed Doubles        Mixed       GOLD
# 2          Curling  beijing-2022  Mixed Doubles        Mixed     SILVER
# 3          Curling  beijing-2022  Mixed Doubles        Mixed     SILVER
# 4          Curling  beijing-2022  Mixed Doubles        Mixed     BRONZE
#
#   participant_type participant_title     athlete_full_name country_name  \
# 0         GameTeam             Italy  Stefania CONSTANTINI        Italy
# 1         GameTeam             Italy          Amos MOSANER        Italy
# 2         GameTeam            Norway      Kristin SKASLIEN       Norway
# 3         GameTeam            Norway    Magnus NEDREGOTTEN       Norway
# 4         GameTeam            Sweden         Almida DE VAL       Sweden
#
#   country_code country_3_letter_code  year olympic_location  \
# 0           IT                   ITA  2022          beijing
# 1           IT                   ITA  2022          beijing
# 2           NO                   NOR  2022          beijing
# 3           NO                   NOR  2022          beijing
# 4           SE                   SWE  2022          beijing
#
#   participant_title_cleaned
# 0                     Italy
# 1                     Italy
# 2                    Norway
# 3                    Norway
# 4                    Sweden
